# %% [markdown]
# # MINERVA toolbox examples

# %%
# %cd /dls/science/users/rpy65944/I07_work/MINERVA_analysis
# %pip install MINERVA_toolbox/
# Out:
# /dls/science/users/rpy65944/I07_work/MINERVA_analysis
# Defaulting to user installation because normal site-packages is not writeable
# Processing ./MINERVA_toolbox
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for MINERVA-toolbox: filename=minerva_toolbox-2026.2.23-py3-none-any.whl size=8175 sha256=ec9ad0b4872d0d9b57cab0230094c46008519db6f6c61a9cc618f317b2e0bb6d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gzlcrmrp/wheels/49/11/c9/45ae860fbbbb609c6cb3742aeaa9f47e7ff2ba4631e3415242
# Successfully built MINERVA-toolbox
# ...
#   Attempting uninstall: MINERVA-toolbox
#     Found existing installation: MINERVA-toolbox 2026.2.23
#     Uninstalling MINERVA-toolbox-2026.2.23:
#       Successfully uninstalled MINERVA-toolbox-2026.2.23
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Using interactive widget to explore folder
#
# This option allows you to create a dropdown menu with all files which have a filename containing the string given as scantype.
# Datasets saved using I07 fast_rsm software will be one of three types:
#
#  - IvsQ :  this is a 1d dataset of an azimuthal integration with intensity data, along with 2theta and Q values
#     ``` python
#             plot_i07_list(Path(outfold),scantype='IvsQ')
#     ```
#
#  - Qmap :  this is a 2d dataset of Intensity based on Q in-plane and Q out-of-plane
#     ``` python
#             plot_i07_list(Path(outfold),scantype='Qmap')
#     ```
#
#  - exitangles : this is a 2d dataset of Intensity based on exit angle perpendicular and exit angle parallel
#     ``` python
#             plot_i07_list(Path(outfold),scantype='exitangles')
#     ```
#
# some useful tips when viewing interactive plots
#
# - hovering the mouse over the current plot area shows a readout of the x,y,intensity values below the plot
# - for 2d images the contrast can be adjusted by selecting the crossed arrows from the toolbar on the left, and then clicking and dragging on the colour bar
#   - right-click and drag : increases or decreases the overall range of the colourmap
#   - left-click and drag : moves the upper and lower limits together

# %%
from MINERVA_toolbox.plotting import plot_i07_list
from pathlib import Path

# %%
outfold='/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-02-11'
# %matplotlib widget
plot_i07_list(Path(outfold),scantype='IvsQ')
# Out:
# interactive(children=(Text(value='/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-0…
# interactive(children=(Dropdown(description='IvsQ files', options=('IvsQ_531473_2026-02-11_09h48m29s.hdf5', 'Iv…

# %% [markdown]
# ## Quick comparison plotting
#
# The MINERVA_toolbox has options for quick comparison plots, where given a list of files the functions can create plots for quick comparisons
#
# - compare_ivq_list : this function takes a list of IvsQ datasets and plots them all on the same plot for comparison. There is also an optional setting allowing changing the y-axis to logscale.
#
#     ``` python
#         compare_ivq_list(filepaths,logscale=True)
#     ```
# - compare_qmap_list : this function takes a list of Qmap datasets and plots them in a grid for comparison.
#
#     ``` python
#         compare_qmap_list(filepaths)
#     ```
#
# -

# %%
from MINERVA_toolbox.plotting import compare_qmap_list, compare_ivq_list, plot_ivq_i07
from pathlib import Path

# %%
# %matplotlib widget

outfold=Path('/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-02-11')
filenames=['IvsQ_610009_2026-02-11_09h55m05s.hdf5','IvsQ_432196_2026-02-11_09h52m30s.hdf5']#,'IvsQ_509441_2026-02-11_11h14m28s.hdf5']
filepaths=[ outfold / name for name in filenames]
compare_ivq_list(filepaths,logscale=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

outfold=Path('/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-02-11')
filenames=['Qmap_432196_2026-02-11_09h52m27s.hdf5','Qmap_610009_2026-02-11_09h54m50s.hdf5','Qmap_610009_2026-02-11_09h54m50s.hdf5']#,'Qmap_432196_2026-02-11_09h52m27s.hdf5']
filepaths=[ outfold / name for name in filenames]

compare_qmap_list(filepaths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 filenames=['Qmap_432196_2026-02-11_09h52m27s.hdf5','Qmap_610009_2026-02-11_09h54m50s.hdf5','Qmap_610009_2026-02-11_09h54m50s.hdf5']#,'Qmap_432196_2026-02-11_09h52m27s.hdf5']
#       5 filepaths=[ outfold / name for name in filenames]
# ----> 7 compare_qmap_list(filepaths)
#
# NameError: name 'compare_qmap_list' is not defined

# %%
import h5py
import matplotlib.pyplot as plt
from MINERVA_toolbox.plotting import get_i07_i_q_data
outfold='/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-02-11'
# %matplotlib widget

testivqfiles=['IvsQ_432196_2026-02-11_09h52m30s.hdf5',       'IvsQ_610009_2026-02-11_09h55m05s.hdf5']
h5data=h5py.File(f'{outfold}/{testivqfiles[0]}')

# %%
from pprint import pprint

# %% [markdown]
# ## Extracting datasets to do specialised plots
#
# MINERVA_toolbox also has functions to extract the 1d or 2d datasets from i07 processed files which can then be used in personalised plots
#
# - get_i07_i_q_data : extracts the Intensity and Q values
#
#     ``` python
#         Intensity,q=get_i07_i_q_data(h5data)
#
#     ```
#
# - get_i07_qmap_data : extracts the image intensity, map parallel data, map perpendicular data
#     ``` python
#         map2d,map_perp,map_para=get_i07_qmap_data(h5data)
#
#     ```

# %%
import h5py
import matplotlib.pyplot as plt
from MINERVA_toolbox.plotting import get_i07_i_q_data
outfold='/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-02-11'
# %matplotlib widget

testivqfiles=['IvsQ_432196_2026-02-11_09h52m30s.hdf5',       'IvsQ_610009_2026-02-11_09h55m05s.hdf5']
fig,axs=plt.subplots(figsize=(10,4))
for i,testivqfile in enumerate(testivqfiles):
    h5data=h5py.File(f'{outfold}/{testivqfile}')
    Intensity,q=get_i07_i_q_data(h5data)
    axs.semilogy(q[0],Intensity[0],label=testivqfile)
axs.axvline(2,ls='--')
axs.axvline(6,ls='--',color='red')

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(block=None)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
outfold='/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-02-11'

from MINERVA_toolbox.plotting import get_i07_qmap_data
testqmapfiles=['Qmap_432196_2026-02-11_09h52m27s.hdf5','Qmap_610009_2026-02-11_09h54m50s.hdf5']
fig,axs=plt.subplots(1,2,figsize=(15,8))
axlist=axs.flatten()
# %matplotlib inline

for i,testqmapfile in enumerate(testqmapfiles):
    h5data=h5py.File(f'{outfold}/{testqmapfile}')
    map2d,map_para,map_perp=get_i07_qmap_data(h5data)
    while len(np.shape(map_para))>2:
        map_para=map_para[0]
        map_perp=map_perp[0]
    maplimits=[map_para.min(),map_para.max(),map_perp.min(),map_perp.max()]
    print(maplimits)
    while len(np.shape(map2d))>2:
        map2d=map2d[0]
    axlist[i].imshow(map2d,vmax=map2d.mean()*2,extent=maplimits)
    axlist[i].set_aspect('equal')

plt.tight_layout()
plt.show()
# Out:
# [-3.852321880322384, 4.9707488987531, -0.30935792248888205, 6.656819790758057]
# [-2.9827437, 6.89834, -0.31430548, 7.311784]

# %% [markdown]
# ### Peak fitting
#
# MINERVA_toolbox has some quick fitting functions which make use of the lmfit package.
#
# To carry out the fitting you will need to specify the x,y data you want to fit, along with a list of peaks to fit to the data.
# Each peak will need the following information:
#
# type:  this is the type of peak you want to fit. Currently MINERVA_toolbox supports the following options for the relecant built-in lmfit functions
#
# - "pvoigt": [PseudoVoigtModel](https://lmfit.github.io/lmfit-py/builtin_models.html#lmfit.models.PseudoVoigtModel)
# - "gaussian": [GaussianModel](https://lmfit.github.io/lmfit-py/builtin_models.html#lmfit.models.GaussianModel)
# - "lorentzian": [LorentzianModel](https://lmfit.github.io/lmfit-py/builtin_models.html#lmfit.models.LorentzianModel)
# - "split_lorentzian": [SplitLorentzianModel](https://lmfit.github.io/lmfit-py/builtin_models.html#lmfit.models.SplitLorentzianModel)
# - "skewed_gaussian": [SkewedGaussianModel](https://lmfit.github.io/lmfit-py/builtin_models.html#lmfit.models.SkewedGaussianModel)
#
# settings:  a dictionary of settings you want to set at the start of the fit for that specific peak. Each entry in the setting dictionary needs to be in the format
# ```python
# [name: set_value, minimum_value,maximum_value]
# e.g. 'center':[6.25,6.2,6.3]
# ```

# %%
from MINERVA_toolbox.plotting import peakfit_and_plot,get_i07_i_q_data
import h5py
import matplotlib.pyplot as plt
outfold='/dls/science/groups/das/ExampleData/i07/fast_rsm_example_data/testing_2026-02-11'
# %matplotlib widget

testivqfiles=['IvsQ_432196_2026-02-11_09h52m30s.hdf5',       'IvsQ_610009_2026-02-11_09h55m05s.hdf5']

h5data=h5py.File(f'{outfold}/{testivqfiles[0]}')
Intensity,q=get_i07_i_q_data(h5data)

peak1 = {'type':'pvoigt',
         'settings':
            {'center':[5.39,5.39,5.40],
             'sigma': [0.02,1e-6,0.021],
             'amplitude': [3,1e-6,10]},
         }
peak3 = {'type':'pvoigt',
         'settings':
            {'center':[5.38,5.378,5.385],
             'sigma': [0.02,1e-6,0.021],
             'amplitude': [3,1e-6,10]},
         }
peak2 = {'type':'pvoigt',
         'settings':
            {'center':[5.41,5.39,5.425],
             'sigma': [0.02,1e-6,0.045],
             'amplitude': [7,1e-6,18]}
         }
peaklist=[peak2,peak1,peak3]       

con1=q>5.3
con2=q<5.55
selection=con1&con2

resultlist=[]

x=q[selection]
y=Intensity[selection]
result=peakfit_and_plot(peaklist,x,y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
result
# Out:
# <h2>Fit Result</h2> <p>Model: (((Model(linear, prefix='bkg_') + Model(pvoigt, prefix='p1_')) + Model(pvoigt, prefix='p2_')) + Model(pvoigt, prefix='p3_'))</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>1950</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>116</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>14</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 0.01595685</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.5644e-04</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1003.40903</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-ali
# ...
